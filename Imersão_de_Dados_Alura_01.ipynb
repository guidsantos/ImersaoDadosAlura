# %% [markdown]
# <a href="https://colab.research.google.com/github/guidsantos/ImersaoDadosAlura/blob/main/Imers%C3%A3o_de_Dados_Alura_01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Aula 01

# %% [markdown]
# ##Código

# %%
import pandas as pd

url_dados = 'https://github.com/alura-cursos/imersaodados3/blob/main/dados/dados_experimentos.zip?raw=true'

dados = pd.read_csv(url_dados, compression = 'zip')
dados
# Out:
#                  id    tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 0      id_000644bb2     com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1      id_000779bfc     com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2      id_000a6266a     com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 3      id_0015fd391     com_droga     48   D1  ... -1.6210 -0.8784 -0.3876 -0.8154
# 4      id_001626bd3     com_droga     72   D2  ...  0.1094  0.2885 -0.3786  0.7125
# ...             ...           ...    ...  ...  ...     ...     ...     ...     ...
# 23809  id_fffb1ceed     com_droga     24   D2  ...  0.0631  0.9171  0.5258  0.4680
# 23810  id_fffb70c0c     com_droga     24   D2  ... -0.2084 -0.1224 -0.2715  0.3689
# 23811  id_fffc1c3f4  com_controle     48   D2  ...  0.2256  0.7592  0.6656  0.3808
# 23812  id_fffcb9e7c     com_droga     24   D1  ...  0.1732  0.7015 -0.6290  0.0740
# ...

# %%
dados.head()
# Out:
#              id tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 0  id_000644bb2  com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1  id_000779bfc  com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2  id_000a6266a  com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 3  id_0015fd391  com_droga     48   D1  ... -1.6210 -0.8784 -0.3876 -0.8154
# 4  id_001626bd3  com_droga     72   D2  ...  0.1094  0.2885 -0.3786  0.7125
#
# [5 rows x 877 columns]

# %%
dados.shape
# Out:
# (23814, 877)

# %%
dados['tratamento']
# Out:
# 0           com_droga
# 1           com_droga
# 2           com_droga
# 3           com_droga
# 4           com_droga
#              ...
# 23809       com_droga
# 23810       com_droga
# 23811    com_controle
# 23812       com_droga
# 23813       com_droga
# Name: tratamento, Length: 23814, dtype: object

# %%
dados['tratamento'].unique
# Out:
# <bound method Series.unique of 0           com_droga
# 1           com_droga
# 2           com_droga
# 3           com_droga
# 4           com_droga
#              ...
# 23809       com_droga
# 23810       com_droga
# 23811    com_controle
# 23812       com_droga
# 23813       com_droga
# Name: tratamento, Length: 23814, dtype: object>

# %%
dados['tempo'].unique()
# Out:
# array([24, 72, 48])

# %%
dados['dose'].unique()
# Out:
# array(['D1', 'D2'], dtype=object)

# %%
dados['droga'].unique()
# Out:
# array(['b68db1d53', 'df89a8e5a', '18bb41b2c', ..., '573c787a2',
#        'b2fe3eca7', 'dd4a96d16'], dtype=object)

# %%
dados['g-0'].unique()
# Out:
# array([ 1.062 ,  0.0743,  0.628 , ...,  0.3942,  0.666 , -0.8598])

# %%
dados['tratamento'].value_counts()
# Out:
# com_droga       21948
# com_controle     1866
# Name: tratamento, dtype: int64

# %%
dados['dose'].value_counts()
# Out:
# D1    12147
# D2    11667
# Name: dose, dtype: int64

# %%
dados['tratamento'].value_counts(normalize = True)
# Out:
# com_droga       0.921643
# com_controle    0.078357
# Name: tratamento, dtype: float64

# %%
dados['tratamento'].value_counts().plot.pie()

# %%
dados['tempo'].value_counts().plot.pie()

# %%
dados['tempo'].value_counts().plot.bar()

# %%
dados_filtrados = dados[dados['g-0'] > 0]
dados_filtrados.head()
# Out:
#              id tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 0  id_000644bb2  com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1  id_000779bfc  com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2  id_000a6266a  com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 6  id_001bd861f  com_droga     24   D2  ...  2.4670  0.0357  0.1351 -0.3179
# 7  id_0020d0484  com_droga     48   D1  ...  0.6633  0.4562 -0.9622  0.0260
#
# [5 rows x 877 columns]

# %% [markdown]
# ##Desafio 01 - Investigar por que a classe tratamento é tão desbalanceada?

# %%
#Desafio - 01
dados_com_droga = dados[dados['tratamento'] == 'com_droga']
dados_com_controle = dados[dados['tratamento'] == 'com_controle']

# %%
dados_com_controle.head()
# Out:
#               id    tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 25  id_0054388ec  com_controle     48   D1  ...  0.8837  0.5534  0.8976  1.0050
# 38  id_0079af0fb  com_controle     24   D1  ...  0.2187  0.0737  0.6498 -1.4820
# 40  id_007bfbb91  com_controle     24   D2  ... -0.5751  0.3362  0.8543  0.9180
# 47  id_008a986b7  com_controle     48   D2  ... -0.4979  0.5281 -0.9245 -0.9367
# 63  id_009d8340f  com_controle     24   D2  ...  0.0949  0.2000 -0.4326  0.9364
#
# [5 rows x 877 columns]

# %%
dados_com_controle['droga'].unique()
# Out:
# array(['cacb2b860'], dtype=object)

# %%
dados_com_droga.head()
# Out:
#              id tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 0  id_000644bb2  com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1  id_000779bfc  com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2  id_000a6266a  com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 3  id_0015fd391  com_droga     48   D1  ... -1.6210 -0.8784 -0.3876 -0.8154
# 4  id_001626bd3  com_droga     72   D2  ...  0.1094  0.2885 -0.3786  0.7125
#
# [5 rows x 877 columns]

# %% [markdown]
# Os dados estão desbalanceados, pois existem um número menor de tratamentos com controle que correspondem as variáveis possíveis para os testes, e elas são realizadas com uma única droga de controle.
# Assim para cada tratamento com controle, pode existir varios tratamentos com droga que iram utilizar daquele controle para validar-se

# %% [markdown]
# ##Desafio 02 - Plotar as 5 últimas linhas da tabela

# %%
dados.tail(5)
# Out:
#                  id    tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 23809  id_fffb1ceed     com_droga     24   D2  ...  0.0631  0.9171  0.5258  0.4680
# 23810  id_fffb70c0c     com_droga     24   D2  ... -0.2084 -0.1224 -0.2715  0.3689
# 23811  id_fffc1c3f4  com_controle     48   D2  ...  0.2256  0.7592  0.6656  0.3808
# 23812  id_fffcb9e7c     com_droga     24   D1  ...  0.1732  0.7015 -0.6290  0.0740
# 23813  id_ffffdd77b     com_droga     72   D1  ... -3.5770 -0.4775 -2.1500 -4.2520
#
# [5 rows x 877 columns]

# %% [markdown]
# ##Desafio 03 - Proporção das classes tratamento.

# %%
dados['tratamento'].value_counts(normalize = True)
# Out:
# com_droga       0.921643
# com_controle    0.078357
# Name: tratamento, dtype: float64

# %% [markdown]
# Temos 92,16% de tratamentos com droga e 7,83% de com controle

# %% [markdown]
# ##Desafio 04 - Quantas tipos de drogas foram investigados.

# %%
todas_drogas = dados['droga'].unique()
len(todas_drogas)
# Out:
# 3289

# %% [markdown]
# Foram investigadas 3289 drogas, sendo uma de controle

# %% [markdown]
# ##Desafio 05: Procurar na documentação o método query(pandas).

# %% [markdown]
# [Link para documentação do método query do pandas](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.query.html?highlight=query#pandas.DataFrame.query)

# %%
#Exemplo utilizando para procurar dados com tempo = 72
dados.query('tempo == 72').head()
# Out:
#               id tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 1   id_000779bfc  com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 4   id_001626bd3  com_droga     72   D2  ...  0.1094  0.2885 -0.3786  0.7125
# 10  id_002452c7e  com_droga     72   D2  ...  0.6648  0.0651 -0.0125  0.2600
# 14  id_002d31e2c  com_droga     72   D1  ... -8.1330 -4.3170 -6.2390  0.9477
# 18  id_003603254  com_droga     72   D2  ... -1.3790 -0.4393 -0.0259  0.9765
#
# [5 rows x 877 columns]

# %%
#Exemplo para procurar dados que fazem tratamento com controle
dados.query('tratamento == "com_controle"').head()
# Out:
#               id    tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 25  id_0054388ec  com_controle     48   D1  ...  0.8837  0.5534  0.8976  1.0050
# 38  id_0079af0fb  com_controle     24   D1  ...  0.2187  0.0737  0.6498 -1.4820
# 40  id_007bfbb91  com_controle     24   D2  ... -0.5751  0.3362  0.8543  0.9180
# 47  id_008a986b7  com_controle     48   D2  ... -0.4979  0.5281 -0.9245 -0.9367
# 63  id_009d8340f  com_controle     24   D2  ...  0.0949  0.2000 -0.4326  0.9364
#
# [5 rows x 877 columns]

# %% [markdown]
# ##Desafio 06: Renomear as colunas tirando o hífen.

# %%
colunas_com_hifen = dados.columns
colunas_sem_hifen = []
for coluna in colunas:
  colunas_sem_hifen.append(coluna.replace('-', ''))
colunas_sem_hifen[5:10]
# Out:
# ['g0', 'g1', 'g2', 'g3', 'g4']

# %%
dados.columns = colunas_sem_hifen

# %%
dados.columns
# Out:
# Index(['id', 'tratamento', 'tempo', 'dose', 'droga', 'g0', 'g1', 'g2', 'g3',
#        'g4',
#        ...
#        'c90', 'c91', 'c92', 'c93', 'c94', 'c95', 'c96', 'c97', 'c98', 'c99'],
#       dtype='object', length=877)

# %%
dados.head()
# Out:
#              id tratamento  tempo dose  ...     c96     c97     c98     c99
# 0  id_000644bb2  com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1  id_000779bfc  com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2  id_000a6266a  com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 3  id_0015fd391  com_droga     48   D1  ... -1.6210 -0.8784 -0.3876 -0.8154
# 4  id_001626bd3  com_droga     72   D2  ...  0.1094  0.2885 -0.3786  0.7125
#
# [5 rows x 877 columns]

# %%
dados['c10'].value_counts()
# Out:
# -10.0000    281
# -1.1350      12
#  1.1030      11
# -1.1000       9
#  1.0280       9
#            ...
#  0.9269       1
#  0.7760       1
#  0.0345       1
# -0.5250       1
#  0.8071       1
# Name: c10, Length: 14617, dtype: int64

# %% [markdown]
# ##Desafio 07: Deixar os gráficos bonitões. (Matplotlib.pyplot)

# %%
import matplotlib.pyplot as plt

# %%
dados.shape[0]
# Out:
# 23814

# %%
dados['tempo'].value_counts().plot.bar()
plt.title('Quantidade de tratamentos')
plt.xlabel('Tempo (h)')
plt.ylabel('Quantidade')
plt.show()

# %% [markdown]
# ##Desafio 08: Resumo do que você aprendeu com os dados

# %% [markdown]
# ###Resumo
#
#
# &nbsp;
# O dataframe que estamos utilizando é o registro de experimentos feitos em células. Foram realizados 23.814 experimentos e cada um possui um id, se o tratamento foi feito com droga ou controle, tempo do tratamento que pode ser de 24, 48 ou 72 horas, dose contendo dois tipos D1 ou D2 e o hash da droga utilizada, as outras 872 colunas são referentes ao genes e o valor de suas reações com o teste.
#
#
# &nbsp;
# No total foram utilizados 3289 drogas diferentes, sendo uma para controle, os testes precisam ter tratamentos com controle, que são responsáveis para sabermos como as células se comportam sem o uso da droga em diferentes condições, foi observado que temos variações entre os tratamentos com controle mas o hash da droga é sempre o mesmo, com isso possível ver se os tratamentos feitos com uma droga x apresentão uma reação válida.
#
#
# &nbsp;
# Foram realizados mais testes com o tempo do tratamento de 48 horas mas a diferença é pequena e o número de testes com doses D1 ou D2 são parecidos. Como cada tramento de controle pode ser usado para validar varios testes com drogas diferentes temos apenas 7,8% de tratamentos com controle e o restante é realizado com drogas.
